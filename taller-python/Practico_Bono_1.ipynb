# %% [markdown]
# <img src="assets/javeriana.png" alt="drawing" width="200"/>
#
# <h1>Procesamiento de Datos a Gran Escala</h1>

# %% [markdown]
# <h2>Bono Practica Python</h2>
#
# ### Fecha: 1 de Agosto de 2026
#
# ### Autor: Lorenzo Ramirez Calderon (ID: 20550074)
#
# ### Docente: John Jairo Corredor
#
# ### Objetivo: Integrar y aplicar los conocimiento obtenidos a traves de los diferentes modulos a traves de diferentes ejercicios que combinen el uso de estructuras condicionales y repetitivas, listas, cadenas y funciones.

# %% [markdown]
# ## CALENTAMIENTO:

# %% [markdown]
# #### MENOR DE DOS PARES: Escriba una función que devuelva el menor de dos números dados *si* ambos números son pares, pero devuelva el mayor si uno o ambos números son impares
#     lesser_of_two_evens(2,4) --> 2
#     lesser_of_two_evens(2,5) --> 5

# %%
def lesser_of_two_evens(a,b):

    if (a%2==0) and (b%2==0): # Para saber si un numero es par se utiliza el operador de modulo
        return min(a,b)
    else:                   # Para los minimos y maximos se utilizan las funciones integradas de python min y max
        return max(a,b)

# %%
# Revisión
lesser_of_two_evens(2,4)
# Out:
# 2

# %%
# Revisión
lesser_of_two_evens(2,5)
# Out:
# 5

# %% [markdown]
# #### GALLETAS DE ANIMALES: Escribir una función que toma una cadena de dos palabras y devuelve True si ambas palabras comienzan con la misma letra
#     animal_crackers('Ciudad Calor') --> True
#     animal_crackers('Lugar Frio') --> False

# %%
def animal_crackers(text):
  words = text.split(' ')  #Se separan las palabras en una lista
  if words[0][0].lower == words[1][0].lower: # Se hace la verificacion convirtiendo las letras a minuscula en caso tal de que haya diferencias de capitalizacion
    return True
  else:
    return False

# %%
# Revisión
animal_crackers('Ciudad Calor')
# Out:
# True

# %%
# Revisión
animal_crackers('Lugar Frio')
# Out:
# False

# %% [markdown]
# #### HACE VEINTE: dados dos enteros, devuelve True si la suma de los enteros es 20 o si uno de los enteros es 20. De lo contrario, devuelve False
#
#     makes_twenty(20,10) --> True
#     makes_twenty(12,8) --> True
#     makes_twenty(2,3) --> False

# %%
def makes_twenty(n1,n2):

    if(n1+n2 == 20) or(n1==20) or (n2==20): # Se reallizan las tres verificaciones correspondientes
        return True
    else: 
        return False

# %%
# Revisión
makes_twenty(20,10)
# Out:
# True

# %%
# Revisión
makes_twenty(2,3)
# Out:
# False

# %%
makes_twenty(12,8)
# Out:
# True

# %% [markdown]
# # Nivel 1

# %% [markdown]
# #### MAYÚSCULAS: Escribir una función que haga mayúscula la primera y cuarta letra de una cadena de texto
#
#     old_macdonald('macdonald') --> MacDonald
#
# Note: `'macdonald'.capitalize()` returns `'Macdonald'`

# %%
def old_macdonald(name):
    return name.capitalize()[0] + name[1:3] + name[3].upper() + name[4:]  # Se utiliza la concatenacion de cadenas junto a slicing para armar la nueva palabra

# %%
# Check
old_macdonald('macdonald')
# Out:
# 'MacDonald'

# %% [markdown]
# #### REVERSA: Dada una oración, retornar la misma oración pero en reversa
#
#     master_yoda('I am home') --> 'home am I'
#     master_yoda('We are ready') --> 'ready are We'
#
# Note: Revisar método .join()
#
#     >>> "--".join(['a','b','c'])
#     >>> 'a--b--c'
#
# Resultado de .join():
#
#     >>> " ".join(['Hello','world'])
#     >>> "Hello world"

# %%
def master_yoda(text):
    words = text.split(' ') # Se separan las palabras en una lista
    reversedwords = []

    for i in range(len(words)-1, -1, -1):
        reversedwords.append(words[i])  # Se recorre la lista en reversa y se añade a la nueva lista


    return " ".join(reversedwords) # Se vuelven a unir las palabras en una misma cadena usando metodo integrado join

# %%
# Revisión
master_yoda('I am home')
# Out:
# 'home am I'

# %%
# Revisión
master_yoda('We are ready')
# Out:
# 'ready are We'

# %% [markdown]
# # Nivel 2

# %% [markdown]
# #### PROBLEMA 33:
#
# Dada una lista de enteros, retornar True si el arreglo tinene un  3  seguido por un  3 .
#
#     has_33([1, 3, 3]) → True
#     has_33([1, 3, 1, 3]) → False
#     has_33([3, 1, 3]) → False

# %%
def has_33(nums):

    for i in range(len(nums)-1): # Se realiza recorrido por el arreglo hasta uno anterior para no exceder a indices que no hacen parte del arreglo
        if(nums[i] == 3) and (nums[i+1] == 3): # Se realiza verificacion de los numeros continuos
            return True

    return False

# %%
# Revisión
has_33([1, 3, 3])
# Out:
# True

# %%
# Revisión
has_33([1, 3, 1, 3])
# Out:
# False

# %%
# Revisión
has_33([3, 1, 3])
# Out:
# False

# %% [markdown]
# #### REPLICADOR: Dada una cadena, devuelve una cadena donde por cada carácter en el original hay tres caracteres REPETIDOS
#     paper_doll('Hello') --> 'HHHeeellllllooo'
#     paper_doll('Mississippi') --> 'MMMiiissssssiiippppppiii'

# %%
def paper_doll(text):
    newString =""

    for char in text: # Para cada caracter se utilizan las operaciones en cadenas y su concatenacion para triplicar cada caracter
        newString += 3*char

    return newString

# %%
# Check
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
# Check
paper_doll('Mississippi')
# Out:
# 'MMMiiissssssiiissssssiiippppppiii'

# %% [markdown]
# #### BLACKJACK: Dados tres enteros entre 1 y 11, si su suma es menor o igual a 21, devuelve su suma. Si su suma excede 21 *y* hay un once, reduce la suma total en 10. Finalmente, si la suma (incluso después del ajuste) excede 21, devuelve 'BUST'
#     blackjack(5,6,7) --> 18
#     blackjack(9,9,9) --> 'BUST'
#     blackjack(9,9,11) --> 19

# %%
def blackjack(a,b,c):
    cards = [a,b,c] # Se convierten los entero a una lista para aprovechar los metodos de esta
    sum_cards = sum(cards) # Suma de cartas usando metodo de sum en la lista

    if sum_cards <= 21: # Verificacion inicial
        return sum_cards
    elif 11 in cards: # Se aprovecha el operador in para verificar existencia del 11
        return sum_cards - 10
    else: # retorno final si no se cumple ninguna de las anteriores condiciones del BlackJack
        return 'BUST'

# %%
# Revisión
blackjack(5,6,7)
# Out:
# 18

# %%
# Revisión
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
# Revisión
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# ## Suerte!
